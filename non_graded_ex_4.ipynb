# %% [markdown]
# Write a simple program for a card Role-Playing Game. Try to use only the concepts you have learned so far in the lectures.
#
# REQUIREMENTS:
#
# 1. Following are the different cards, with their characteristics, available to the player
#
# Name: Diablo
# Health: 100
# Attack: 90
# Defense: 60
#
# Name: Medusa
# Health: 100
# Attack: 70
# Defense: 70
#
# Name: Jester
# Health: 120
# Attack: 60
# Defense: 90
#
# Name: Troll
# Health: 150
# Attack: 40
# Defense: 94
#
# Name: Specter
# Health: 100
# Attack: 70
# Defense: 70
#
# Name: Mist
# Health: 100
# Attack: 75
# Defense: 65
#
# Name: Savage
# Health: 100
# Attack: 90
# Defense: 50
#
# Name: Marauder
# Health: 100
# Attack: 85
# Defense: 50
#
# Name: Wimp
# Health: 110
# Attack: 40
# Defense: 85
#
# Name: Sorcerer
# Health: 100
# Attack: 70
# Defense: 55
#
# 2. Store the above card details using a suitable data structure like list, tuple, dictionary, or any combination of these
# 3. From these cards, assign a random deck of 5 cards to both the player and the computer (opponent).
#     3.1. This should happen whenever a new game begins
# 4. Keep the game running for as long as there are cards in the player's deck or for as long as there are cards in the opponent's deck
#     4.1. Show all the cards that the player has in their deck
#     4.2. Assign a random card to the opponent, and show that to the player, along with the details of that card. Only the details of this random card must be shown.
#     4.3. Ask the player to pick a card from their own deck to fight the opponent's card.
#     4.4. If the attack value of the player's card is more than the health of opponent's card, then the player wins this round.
#     4.5. Otherwise, the player's card will fight with the opponent's card.
#         4.5.1. Calculate the damage the player's card does to the opponent's card. This calculation should take care of the fact that the opponent's card will first defend the attack using its 'Defense' value. And if there is no defense value, only then will the player's attack value will affect the opponent card's health.
#
#         e.g.,
#         Player card
#
#         Name: Wimp
#         Health: 110
#         Attack: 40
#         Defense: 85
#
#
#         Opponent card
#
#         Name: Sorcerer
#         Health: 100
#         Attack: 70
#         Defense: 55
#
#         If the Wimp attacks Sorcerer, first, it will only affect Sorcerer's 'Defense' value. Sorcerer's defense value will decrease by the the attack value of player's Wimp card. Therefore, after the attack, the defense value will change from 55 to 15, as 55 - 40 = 15. Therefore,
#
#         Opponent card
#
#         Name: Sorcerer
#         Health: 100
#         Attack: 70
#         Defense: 15
#
#         Now, if in the next round, Wimp attacks Sorcerer again, then Sorcerer's defense value will decrease to 0, but its health will also be affected. The health will be affected by 25 points, as 40 - 15 = 25. So, Sorcerer's health will now decrease from 100 to 75
#
#         Opponent card
#
#         Name: Sorcerer
#         Health: 75
#         Attack: 70
#         Defense: 0
#
#         Now, let's say in a later round, the player uses the Marauder card, which has an attack value of 85, and the computer is using Sorcerer, whose health value is 75.
#
#         In that case, Sorcerer will be defeated, as 85 > 75. When this happens, remove the Sorcerer card from the deck of the opponent.
#
#         Display properly all these changes to the player at every round, so that they know how their attacks affected the round and what they can do next.
#
#         DO NOT just show the card details. Write proper statements, describing the process, as you may have seen in the demonstration given by the teacher
#
#         4.5.2. After the user's turn, make sure all the card values adjusted accordingly, just as described above.
#         4.5.3. ONLY a card's 'Defense' and 'Health' value changes after an attack. And once the 'Health' value of a card reaches 0 or drops below it, that card MUST be removed from the deck.
#         4.5.4. After the player's turn, pause the second for some seconds, e.g., time.sleep(3) will pause the game for 3 seconds.
#     4.6. Display that now it's the opponent's turn.
#     4.7. Make sure there are cards available in opponent's deck. If there aren't, then the game ends and the player wins.
#     4.8. If there are still cards available in opponent's deck, draw a random card from the opponent's deck, and display its details to the player.
#     4.9. Then display the cards available in the player's deck.
#     4.10 Ask the user to pick one card from their own deck to fight the opponent's card.
#     4.11. REPEAT THE SAME LOGIC AS STATED FROM POINT 4.4 TO 4.5.3. But this time, from the perspective of the opponent.
#     4.12. After the opponent's turn is over, display that a new round will begin in some seconds.
# 5. If it's found that the opponent has no card in their deck, then display a message stating player is the winner, otherwise display that the opponent won.

# %%
import random 
import time
from copy import deepcopy

card_deck = {
    "a": {"Name":"Diablo","Health": 100, "Attack": 90, "Defense": 60},
    "b": {"Name":"Medusa","Health": 100, "Attack": 70, "Defense": 70},
    "c": {"Name":"Jester","Health": 120, "Attack": 60, "Defense": 90},
    "d": {"Name":"Troll","Health": 150, "Attack": 40, "Defense": 94},
    "e": {"Name":"Specter","Health": 100, "Attack": 70, "Defense": 70},
    "f": {"Name":"Mist", "Health": 100, "Attack": 75, "Defense": 65},
    "g": {"Name":"Savage", "Health": 100, "Attack": 90, "Defense": 50},
    "h": {"Name":"Marauder", "Health": 100, "Attack": 85, "Defense": 50},
    "i": {"Name":"Wimp","Health": 110, "Attack": 40, "Defense": 85},
    "j": {"Name":"Sorcerer","Health": 100, "Attack": 70, "Defense": 55}
}
deck_size = 3


#The following is used to draw randomly n number of cards from the deck, where n = deck_size
player = random.sample(list(card_deck.items()), deck_size)
opponent = random.sample(list(card_deck.items()), deck_size)


player_deck_copy = dict(player)
opponent_deck_copy = dict(opponent)

player_deck = deepcopy(player_deck_copy)
opponent_deck = deepcopy(opponent_deck_copy)

def inner1(name1,name2,attack,defence,health):
    print(f"Both {name1} and {name2} are now battling it out \nUsing your warrior {name1},")
    print(f"  you attacked with a force of {attack} Newton")
    print(f"  and your opponent resisted it with a force of {defence} Nekton.")
    print(f"  At the end of this turn,your opponent's health is {health}")

def inner2(name1,name2,attack,defence,health):
    print(f"Both {name1} and {name2} are now battling it out \nUsing your warrior {name1},")
    print(f"  your opponent's attack with a force of {attack} Newton")
    print(f"  and your resisted it with a force of {defence} Nekton.")
    print(f"  At the end of this turn,your health is {health}")


while len(player_deck)>0 and len(opponent_deck)>0:
    print()
    print("Player's turn: ")
    for k in player_deck.keys():
        print(f"card number: {k}")
        print(f"Name: {player_deck[k]['Name']}")
        print(f"Health: {player_deck[k]['Health']}")
        print(f"Attack: {player_deck[k]['Attack']}")
        print(f"Defense: {player_deck[k]['Defense']}")
        print()
    
    opp = random.choice(list(opponent_deck.keys()))
    print(f"Your opponent has chosen {opponent_deck[opp]['Name']} for this round")
    print()
    print(f"Health: {opponent_deck[opp]['Health']}")
    print(f"Attack: {opponent_deck[opp]['Attack']}")
    print(f"Defense: {opponent_deck[opp]['Defense']}")
    print()
    number = input("Select the card number you want to dispatch:")
    print()
    if player_deck[number]['Attack'] >= (opponent_deck[opp]['Health']+opponent_deck[opp]['Defense']):
        inner1(player_deck[number]['Name'],opponent_deck[opp]['Name'],player_deck[number]['Attack'],opponent_deck[opp]['Defense'],0)
        opponent_deck.pop(opp)
        if len(player_deck)>0 and len(opponent_deck)>0:
            print(f"\nNext round will begin in 3 seconds")
            time.sleep(3)
        continue
    else:
        if opponent_deck[opp]['Defense']>=player_deck[number]['Attack']:
           opponent_deck[opp]['Defense']=opponent_deck[opp]['Defense']-player_deck[number]['Attack']
           inner1(player_deck[number]['Name'],opponent_deck[opp]['Name'],player_deck[number]['Attack'],player_deck[number]['Attack'],opponent_deck[opp]['Health'])
        else:
            opponent_deck[opp]['Health']=opponent_deck[opp]['Health']+opponent_deck[opp]['Defense']-player_deck[number]['Attack']
            inner1(player_deck[number]['Name'],opponent_deck[opp]['Name'],player_deck[number]['Attack'],opponent_deck[opp]['Defense'],opponent_deck[opp]['Health'])
            opponent_deck[opp]['Defense']=0

    print()
    print("Opponent's turn: ")
    print(f"Now your opponent will attack in 3 seconds: \n")
    time.sleep(3)
    if opponent_deck[opp]['Attack'] >= (player_deck[number]['Health']+player_deck[number]['Defense']):
        inner2(player_deck[number]['Name'],opponent_deck[opp]['Name'],opponent_deck[opp]['Attack'],player_deck[number]['Defense'],0)
        player_deck.pop(number)
        if len(player_deck)>0 and len(opponent_deck)>0:
            print(f"\nNext round will begin in 3 seconds")
            time.sleep(3)
        continue
    else:
        if player_deck[number]['Defense']>=opponent_deck[opp]['Attack']:
           player_deck[number]['Defense']=player_deck[number]['Defense']-opponent_deck[opp]['Attack']
           inner2(player_deck[number]['Name'],opponent_deck[opp]['Name'],opponent_deck[opp]['Attack'],opponent_deck[opp]['Attack'],player_deck[number]['Health'])
           if len(player_deck)>0 and len(opponent_deck)>0:
            print(f"\nNext round will begin in 3 seconds")
            time.sleep(3)
           continue
        else:
            player_deck[number]['Health']=player_deck[number]['Health']+player_deck[number]['Defense']-opponent_deck[opp]['Attack']
            inner2(player_deck[number]['Name'],opponent_deck[opp]['Name'],opponent_deck[opp]['Attack'],player_deck[number]['Defense'],player_deck[number]['Health'])
            player_deck[number]['Defense']=0
            if len(player_deck)>0 and len(opponent_deck)>0:
                print(f"\nNext round will begin in 3 seconds")
                time.sleep(3)
            continue

if len(player_deck)==0:
    print()
    print("Sorry, you lost the game.")

if len(opponent_deck)==0:
    print()
    print("Congratulations, you have won the game.")
# Out:
# Player's turn:
# card number: f
# Name: Mist
# Health: 100
# Attack: 75
# Defense: 65
#
# card number: h
# Name: Marauder
# Health: 100
# Attack: 85
# Defense: 50
#
# card number: g
# Name: Savage
# Health: 100
# Attack: 90
# Defense: 50
#
# Your opponent has chosen Mist for this round
#
# Health: 100
# Attack: 75
# Defense: 65
#
#
# Both Savage and Mist are now battling it out
# Using your warrior Savage,
#   you attacked with a force of 90 Newton
#   and your opponent resisted it with a force of 65 Nekton.
#   At the end of this turn,your opponent's health is 75
#
# Opponent's turn:
# Now your opponent will attack in 3 seconds:
#
# Both Savage and Mist are now battling it out
# Using your warrior Savage,
#   your opponent's attack with a force of 75 Newton
#   and your resisted it with a force of 50 Nekton.
#   At the end of this turn,your health is 75
#
# Next round will begin in 3 seconds
#
# Player's turn:
# card number: f
# Name: Mist
# Health: 100
# Attack: 75
# Defense: 65
#
# card number: h
# Name: Marauder
# Health: 100
# Attack: 85
# Defense: 50
#
# card number: g
# Name: Savage
# Health: 75
# Attack: 90
# Defense: 0
#
# Your opponent has chosen Mist for this round
#
# Health: 75
# Attack: 75
# Defense: 0
#
#
# Both Savage and Mist are now battling it out
# Using your warrior Savage,
#   you attacked with a force of 90 Newton
#   and your opponent resisted it with a force of 0 Nekton.
#   At the end of this turn,your opponent's health is 0
#
# Next round will begin in 3 seconds
#
# Player's turn:
# card number: f
# Name: Mist
# Health: 100
# Attack: 75
# Defense: 65
#
# card number: h
# Name: Marauder
# Health: 100
# Attack: 85
# Defense: 50
#
# card number: g
# Name: Savage
# Health: 75
# Attack: 90
# Defense: 0
#
# Your opponent has chosen Marauder for this round
#
# Health: 100
# Attack: 85
# Defense: 50
#
#
# Both Marauder and Marauder are now battling it out
# Using your warrior Marauder,
#   you attacked with a force of 85 Newton
#   and your opponent resisted it with a force of 50 Nekton.
#   At the end of this turn,your opponent's health is 65
#
# Opponent's turn:
# Now your opponent will attack in 3 seconds:
#
# Both Marauder and Marauder are now battling it out
# Using your warrior Marauder,
#   your opponent's attack with a force of 85 Newton
#   and your resisted it with a force of 50 Nekton.
#   At the end of this turn,your health is 65
#
# Next round will begin in 3 seconds
#
# Player's turn:
# card number: f
# Name: Mist
# Health: 100
# Attack: 75
# Defense: 65
#
# card number: h
# Name: Marauder
# Health: 65
# Attack: 85
# Defense: 0
#
# card number: g
# Name: Savage
# Health: 75
# Attack: 90
# Defense: 0
#
# Your opponent has chosen Jester for this round
#
# Health: 120
# Attack: 60
# Defense: 90
#
#
# Both Savage and Jester are now battling it out
# Using your warrior Savage,
#   you attacked with a force of 90 Newton
#   and your opponent resisted it with a force of 90 Nekton.
#   At the end of this turn,your opponent's health is 120
#
# Opponent's turn:
# Now your opponent will attack in 3 seconds:
#
# Both Savage and Jester are now battling it out
# Using your warrior Savage,
#   your opponent's attack with a force of 60 Newton
#   and your resisted it with a force of 0 Nekton.
#   At the end of this turn,your health is 15
#
# Next round will begin in 3 seconds
#
# Player's turn:
# card number: f
# Name: Mist
# Health: 100
# Attack: 75
# Defense: 65
#
# card number: h
# Name: Marauder
# Health: 65
# Attack: 85
# Defense: 0
#
# card number: g
# Name: Savage
# Health: 15
# Attack: 90
# Defense: 0
#
# Your opponent has chosen Jester for this round
#
# Health: 120
# Attack: 60
# Defense: 0
#
#
# Both Mist and Jester are now battling it out
# Using your warrior Mist,
#   you attacked with a force of 75 Newton
#   and your opponent resisted it with a force of 0 Nekton.
#   At the end of this turn,your opponent's health is 45
#
# Opponent's turn:
# Now your opponent will attack in 3 seconds:
#
# Both Mist and Jester are now battling it out
# Using your warrior Mist,
#   your opponent's attack with a force of 60 Newton
#   and your resisted it with a force of 60 Nekton.
#   At the end of this turn,your health is 100
#
# Next round will begin in 3 seconds
#
# Player's turn:
# card number: f
# Name: Mist
# Health: 100
# Attack: 75
# Defense: 5
#
# card number: h
# Name: Marauder
# Health: 65
# Attack: 85
# Defense: 0
#
# card number: g
# Name: Savage
# Health: 15
# Attack: 90
# Defense: 0
#
# Your opponent has chosen Jester for this round
#
# Health: 45
# Attack: 60
# Defense: 0
#
#
# Both Savage and Jester are now battling it out
# Using your warrior Savage,
#   you attacked with a force of 90 Newton
#   and your opponent resisted it with a force of 0 Nekton.
#   At the end of this turn,your opponent's health is 0
#
# Next round will begin in 3 seconds
#
# Player's turn:
# card number: f
# Name: Mist
# Health: 100
# Attack: 75
# Defense: 5
#
# card number: h
# Name: Marauder
# Health: 65
# Attack: 85
# Defense: 0
#
# card number: g
# Name: Savage
# Health: 15
# Attack: 90
# Defense: 0
#
# Your opponent has chosen Marauder for this round
#
# Health: 65
# Attack: 85
# Defense: 0
#
#
# Both Savage and Marauder are now battling it out
# Using your warrior Savage,
#   you attacked with a force of 90 Newton
#   and your opponent resisted it with a force of 0 Nekton.
#   At the end of this turn,your opponent's health is 0
#
# Congratulations, you have won the game.
